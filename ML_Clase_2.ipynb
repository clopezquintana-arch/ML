# %% [markdown]
# # Regresión lineal
#
# ## Datos simulados
#
# En general, es difícil que los datos sigan una tendencia exactamente lineal. Por eso, a veces se pueden simular datos que sigan una tendencia deseada.

# %%
import numpy as np

# %%
# Crear datos de entrenamiento y prueba
np.random.seed(0) # Fijo una semilla para que el algoritmo arranque siempre del mismo pto así los nros aleatorios generados son siempre los mismos
N1=1000
# Generamos datos aleatorios con distribución normal
X1 = np.random.randn(N1, 1)
# Notar que la recta generada se centra en una ordenada de valor 2 y una pendiente de valor 3
y1 = 2 + 3 * X1 + np.random.randn(N1, 1)

# %% [markdown]
# ### Gráfico exploratorio
#
# Veamos con el paquete `matplotlib.pyplot` el gráfico de cómo se vinculan `X` e `y`. Para eso, usaremos el comando `scatter`:

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(X1, y1, c = "blue", s = 20)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Relación lineal")
plt.show()

# %% [markdown]
# ### Estimación de los parámetros
#
# Para encontrar la recta que mejor ajusta a estos datos, el paquete `sklearn` tiene la función `LinearRegression()`. Luego se pide buscar la recta que mejor ajusta a estos datos con el método `.fit()`

# %%
from sklearn.linear_model import LinearRegression
# Le informamos a Python que vamos a hacer una regresión lineal
reg_lin = LinearRegression()
# Una vez que sabe que vamos a hacer una regresión lineal, le pedimos que la ajuste a los datos
reg_lin.fit(X1,y1)
# Out:
# LinearRegression()

# %%
# Ordenada (cercano a 2) y pendiente (cercano a 3)
print([reg_lin.intercept_,reg_lin.coef_])
# Out:
# [array([2.01221825]), array([[2.9690942]])]

# %%
# Vamos a graficar cómo ajusta el modelo a los datos, para eso, tomamos valores entre el mínimo y el máximo de X1
X1_pred= np.linspace(np.min(X1),np.max(X1),2).reshape(-1, 1)
y1_pred = reg_lin.predict(X1_pred)
y1_real = 2+3*X1_pred

# %%
# Datos
plt.scatter(X1, y1, c = "blue", s = 20,alpha=0.5)
# Recta estimada
plt.text(-2,5,"Recta estimada",c="red")
plt.plot(X1_pred,y1_pred,c="red")
# Recta real
plt.text(-2,6,"Recta real",c="green")
plt.plot(X1_pred,y1_real,c="green")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Relación lineal")
plt.show()

# %% [markdown]
# ### Seaborn
#
# Otra forma de hacer esto mismo directamente es con el paquete `seaborn`

# %%
import seaborn as sns

# %%
sns.regplot(x=X1,y=y1)
plt.show()

# %% [markdown]
# ### Tendencia cuadrática
#
# Supongamos que estos mismos datos se relacionan de forma cuadrática con la variable `y2`:

# %%
# Notar que la recta generada se centra en una ordenada de valor 2 y una pendiente de valor 3 y coeficiente principal 1.5
X1_cuad=X1**2
y2 = 2 + 3 * X1+ 1.5 * X1_cuad + np.random.randn(N1, 1)

# %%
plt.scatter(X1, y2, c = "blue", s = 20)
plt.xlabel("X")
plt.ylabel("y")
plt.title("Relación cuadrática")
plt.show()

# %%
# Le informamos a Python que vamos a hacer una regresión lineal
reg_lin2 = LinearRegression()
# Una vez que sabe que vamos a hacer una regresión lineal, le pedimos que la ajuste a los datos
reg_lin2.fit(X1, y2)
# Out:
# LinearRegression()

# %%
# Vamos a graficar cómo ajusta el modelo a los datos, para eso, tomamos valores entre el mínimo y el máximo de X1
N2=100
X2_pred= np.linspace(np.min(X1),np.max(X1),N2).reshape(-1, 1)
y2_pred = reg_lin2.predict(X2_pred)

# %%
# Datos
plt.scatter(X1, y2, c = "blue", s = 20,alpha=0.5)
# Recta estimada
plt.plot(X2_pred,y2_pred,c="red")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Relación cuadrática")
plt.show()

# %% [markdown]
# Vemos que la recta no es representativa de los datos, sobre todo aquellos con valores de `X` positivos. Sin embargo, la regresión lineal no siempre se dispone en forma de recta, si se agregan más variables, puede tomar otra forma la predicción ya que se generan más combinaciones entre variables. Lo importante de la regresión lineal es que el modelo considere la **suma** de variables multiplicadas por sus coeficientes.
#
# En este caso, tomaremos un modelo cuadrático, considerando las variables `X1` y su cuadrado:

# %%
X1=np.array([c for x in X1 for c in x]).reshape(N1,)
X1_cuad=X1**2

# %%
import pandas as pd
df1=pd.DataFrame({"X1":X1,"X1_cuad":X1_cuad})

# %%
print(df1)
# Out:
#            X1   X1_cuad
# 0    1.764052  3.111881
# 1    0.400157  0.160126
# 2    0.978738  0.957928
# 3    2.240893  5.021602
# 4    1.867558  3.487773
# ..        ...       ...
# 995  0.412871  0.170462
# 996 -0.198399  0.039362
# 997  0.094192  0.008872
# 998 -1.147611  1.317011
# 999 -0.358114  0.128246
#
# [1000 rows x 2 columns]

# %%
# Le informamos a Python que vamos a hacer una regresión lineal
reg_cuad = LinearRegression()
# Una vez que sabe que vamos a hacer una regresión lineal, le pedimos que la ajuste a los datos
reg_cuad.fit(df1, y2)
# Out:
# LinearRegression()

# %%
print(reg_cuad.intercept_)
print(reg_cuad.coef_)
print([reg_cuad.intercept_,reg_cuad.coef_])
# Out:
# [1.99474358]
# [[2.96077882 1.45109289]]
# [array([1.99474358]), array([[2.96077882, 1.45109289]])]

# %%
df1_pred=pd.DataFrame({"X1":X2_pred.reshape(N2,)})
df1_pred["X1_cuad"]=df1_pred["X1"]**2
# Vamos a graficar cómo ajusta el modelo a los datos, para eso, tomamos valores entre el mínimo y el máximo de X1
y3_pred = reg_cuad.predict(df1_pred)

# %%
# Datos
plt.scatter(X1, y2, c = "blue", s = 20,alpha=0.5)
# Recta estimada
plt.text(-2,5,"Recta estimada",c="red")
plt.plot(X2_pred,y2_pred,c="red")
# Parábola estimada
plt.plot(X2_pred,y3_pred,c="green")
plt.text(-2,6,"Parábola estimada",c="green")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Relación cuadrática")
plt.show()

# %% [markdown]
# ## Overfitting

# %% [markdown]
# Supongamos que usamos el primer modelo lineal (base de entrenamiento), para predecir los valores de la relación cuadrática (base de testeo).

# %%
y2_pred_lin=reg_lin.predict(X2_pred)

# %% [markdown]
# Vemos que la estimación es aún peor que la anterior, porque se basó en las respuestas lineales que no se pueden extrapolar a estas respuestas cuadráticas.

# %%
# Datos
plt.scatter(X1, y2, c = "blue", s = 20,alpha=0.5)
# Recta estimada
plt.text(-2,5,"Recta estimada",c="red")
plt.plot(X2_pred,y2_pred_lin,c="red")
plt.xlabel("X")
plt.ylabel("y")
plt.title("Relación cuadrática")
plt.show()

# %% [markdown]
# Se ve también al comparar las métricas el overfitting

# %%
from sklearn.metrics import mean_squared_error
y1_pred=reg_lin.predict(X1.reshape(-1,1))
y2_pred_lin=reg_lin.predict(X1.reshape(-1,1))
train_mse = mean_squared_error(y1, y1_pred)
test_mse = mean_squared_error(y2, y2_pred_lin)
print(train_mse)
print(test_mse)
# Out:
# 0.9364031961476974
# 6.772896166028153

# %% [markdown]
# En general, no es buena idea utilizar datos de distintas bases para dividir en base de entrenamiento y testeo.
#
# Por lo tanto, conviene agarrar una porción de los mismos datos para entrenar (generalmente entre el 70% y el 80%) con el siguiente comando:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2)

# %%
reg_lin3 = LinearRegression()
reg_lin3.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_pred_train=reg_lin3.predict(X_train.reshape(-1,1))
y_pred_test=reg_lin3.predict(X_test.reshape(-1,1))

# %%
y_rec_train=reg_lin3.predict(X1_pred)
y_rec_test=reg_lin3.predict(X1_pred)

# %%
# Datos entrenamiento
plt.scatter(X_train, y_train, c = "blue", s = 20,alpha=0.5)
plt.text(-2,5,"Datos entrenamiento",c="blue")
# Datos testeo
plt.scatter(X_test, y_test, c = "red", s = 20,alpha=0.5)
plt.plot(X1_pred, y_rec_train, c = "black")
plt.text(-2,6,"Datos testeo",c="red")
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %%
train_mse = mean_squared_error(y_train, y_pred_train)
test_mse = mean_squared_error(y_test, y_pred_test)
print(train_mse)
print(test_mse)
# Out:
# 0.9401877285295507
# 0.9229878938553934

# %% [markdown]
# ## Variables distintas

# %% [markdown]
# A veces, las tendencias pueden no ser lineales ni cuadráticas, sino que no se observa una tendencia lineal ya que involucra a distintas variables. Veamos el siguiente ejemplo:

# %%
# Crear datos de entrenamiento y prueba
np.random.seed(0)
# Generamos datos aleatorios con distribución normal
X1 = np.random.randn(N1, 1)
# Generamos otros datos aleatorios con distribución uniforme
X2 = 2+4*np.random.rand(N1, 1);X2=X2**2
# Notar que la recta generada se centra en una ordenada de valor 2 y una pendiente de valor 3
y4 = 2 + 3 * X1 +5*X2+ np.random.randn(N1, 1)

# %%
plt.scatter(X1, y4, c = "blue", s = 20)
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %% [markdown]
# Si bien la tendencia no es lineal en la variable `X1`, si planteamos un modelo lineal con ambas variables, vemos que las predicciones se ajustan bien a los datos:

# %%
df2=pd.DataFrame(X1,columns=["X1"])
df2["X2"]=X2
reg_lin4 = LinearRegression()
reg_lin4.fit(df2,y4)
y4_pred=reg_lin4.predict(df2)

# %%
plt.scatter(X1, y4, c = "blue", s = 20,alpha=0.5)
plt.scatter(X1, y4_pred, c = "red", marker = "x",alpha=0.5)
plt.xlabel("X")
plt.ylabel("y")
plt.show()

# %% [markdown]
# # Base real
#
# La siguiente base "home_sales_nyc.csv" describe datos sobre ventas inmobiliarias en la ciudad de Nueva York (disponible en [este link](https://github.com/DataScienceForPublicPolicy/diys/tree/main/data) )

# %%
# El link a la base de datos como string
url = 'https://raw.githubusercontent.com/DataScienceForPublicPolicy/diys/main/data/home_sales_nyc.csv'
# Se usa la librería pandas para leer el .csv
df = pd.read_csv(url)

# %% [markdown]
# ## Inspección de la base
#
# Para verificar que la base está bien cargada, visualizamos las primeras 5 filas de la misma:

# %%
df.head()
# Out:
#    time.index  borough neighborhood  building.class.category  zip.code  \
# 0          14        2     BATHGATE  01 ONE FAMILY DWELLINGS     10457
# 1         162        2     BATHGATE  01 ONE FAMILY DWELLINGS     10457
# 2         298        2     BATHGATE  01 ONE FAMILY DWELLINGS     10457
# 3         179        2     BATHGATE  01 ONE FAMILY DWELLINGS     10457
# 4         336        2     BATHGATE  01 ONE FAMILY DWELLINGS     10457
#
#    residential.units  commercial.units  total.units  land.square.feet  \
# 0                  1                 0            1              2500
# 1                  1                 0            1              1578
# 2                  1                 0            1              1694
# 3                  1                 0            1              1694
# 4                  1                 0            1              3525
#
#    gross.square.feet  year.built  sale.price   sale.date  sale.year  age
# 0               1474        1901    241500.0  2018-08-17       2018  117
# 1               1470        1899    180000.0  2018-03-22       2018  119
# 2               1497        1899    246000.0  2017-11-06       2017  118
# 3               1497        1899    255000.0  2018-03-05       2018  119
# 4               1340        1899    380250.0  2017-09-29       2017  118

# %% [markdown]
# Llas 5 filas que se muestran no son las totales de la base de datos, son sólo las que se muestran.
#
# La primer columna no se corresponde con ninguna variable y hace referencia al índice, utilizado para recorrer las distintas filas.
#
# Para seguir analizando la base, vamos a apelar al método `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12668 entries, 0 to 12667
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   time.index               12668 non-null  int64
#  1   borough                  12668 non-null  int64
#  2   neighborhood             12668 non-null  object
#  3   building.class.category  12668 non-null  object
#  4   zip.code                 12668 non-null  int64
#  5   residential.units        12668 non-null  int64
#  6   commercial.units         12668 non-null  int64
#  7   total.units              12668 non-null  int64
#  8   land.square.feet         12668 non-null  int64
#  9   gross.square.feet        12668 non-null  int64
#  10  year.built               12668 non-null  int64
#  11  sale.price               12668 non-null  float64
#  12  sale.date                12668 non-null  object
#  13  sale.year                12668 non-null  int64
#  14  age                      12668 non-null  int64
# dtypes: float64(1), int64(11), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# No toda variable que sea un número debe considerarse numérica. Por ejemplo, los distritos se diferencian con números pero son más como un nombre, no es que indica un orden o algo (son variables cualitativas, no cuantitativas).

# %% [markdown]
# Haremos foco ahora en las siguientes variables:
#
# * gross.square.feet: superficie del inmueble (cuantitativa)
#
# * sale.price: precio de venta (cuantitativa)
#
# Se puede pensar que estas variables están vinculadas, ya que intuitivamente, a medida que los inmuebles son más grandes, más precio de venta tendrán.

# %% [markdown]
# ## Gráfico exploratorio
#
# Para analizar esta dependencia, hacemos un gráfico de dispersión ("scatterplot" en inglés), donde cada inmueble se corresponde con un punto en el gráfico, cuya coordenada horizontal es la superficie, y la coordenada vertical es el precio de venta.

# %%
# Creo un scatterplot que considere la base de datos df como parámetro
# fijando la coordenada x como la superficie y la coordenada y como el precio de venta
sns.scatterplot(data=df,x="gross.square.feet",y="sale.price",alpha=0.5)
# Al gráfico g se le agregan nombres adecuados para los ejes
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
# Este comando obliga a Python a mostrar el gráfico
plt.show()

# %% [markdown]
# # División en train y test

# %%
# Variable de respuesta
resp="sale.price"
from sklearn.model_selection import train_test_split
df_train, df_test, y_train, y_test = train_test_split(df.loc[:,df.columns!=resp], df[resp], test_size = 0.3, random_state = 25)

# %% [markdown]
# ## Regresión lineal simple

# %%
# covs representa la covariable (superficie)
covs=["gross.square.feet"]
X_train=df_train[covs].copy()
X_test=df_test[covs].copy()
# Se inicializa la regresión
mod=LinearRegression()
# Se buscan los valores óptimos de a y b para los datos de la base
mod.fit(X_train,y_train)
# El valor óptimo de a se obtiene con "intercept_" y el de b con ".coef_".
# Como se devuelven listas, se convierten a variables numéricas con "float"
print([float(mod.intercept_),float(mod.coef_)])
# Out:
# [-55029.47531252727, 473.7218634154894]
# /tmp/ipykernel_8391/2078712798.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print([float(mod.intercept_),float(mod.coef_)])

# %% [markdown]
# ## Evaluación gráfica
#
#
# Para evaluar gráficamente el modelo, se puede unir con una línea dos valores predichos, tomando los mínimos y máximos de la superficie del inmueble como coordenada $x$ y tomando sus estimaciones como coordenada $y$.

# %%
# Calculo el mínimo y el máximo
minX=df_train['gross.square.feet'].min()
maxX=df_train['gross.square.feet'].max()
# Genero una nueva base con las predicciones
df_pred=pd.DataFrame({"gross.square.feet":[minX,maxX]})
df_pred["sale.price"]=mod.predict(df_pred)
# Uno ambas predicciones con una línea
sns.scatterplot(data=df_train,x="gross.square.feet",y=y_train,alpha=0.5)
sns.lineplot(data=df_pred,x="gross.square.feet",y="sale.price",alpha=0.7,color="red")
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %% [markdown]
# También podemos ver cómo ajusta a los datos de testeo

# %%
# Calculo el mínimo y el máximo
minX=df_test['gross.square.feet'].min()
maxX=df_test['gross.square.feet'].max()
# Genero una nueva base con las predicciones
df_pred=pd.DataFrame({"gross.square.feet":[minX,maxX]})
df_pred["sale.price"]=mod.predict(df_pred)
# Uno ambas predicciones con una línea
sns.scatterplot(data=df_test,x="gross.square.feet",y=y_test,alpha=0.5)
sns.lineplot(data=df_pred,x="gross.square.feet",y="sale.price",alpha=0.7,color="red")
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %% [markdown]
# ## Evaluación numérica del modelo
#
#
# Un valor estándard para evaluar el rendimiento de un modelo, es la magnitud denominada $R^2$. Este valor evalúa las similitudes entre la variable independiente y las predicciones de la variable independiente. Sus valores van entre 0 y 1, y mientras más cercanos esté a 1, mejor es el modelo para representar los datos.

# %%
mod.score(X_train,y_train)
# Out:
# 0.25446238004630717

# %% [markdown]
# Vemos que el valor de $R^2$ no es tan alto, en el gráfico se ve que para algunos valores altos de la superficie, la recta queda lejos de algunos inmuebles con precios muy altos de venta.

# %%
mod.score(X_test,y_test)
# Out:
# 0.25282181813724447

# %% [markdown]
# Otra métrica utilizada para comparar modelos es el error cuadrático medio

# %%
from sklearn.metrics import mean_squared_error
mse_train=mean_squared_error(mod.predict(X_train),y_train)
print("MSE train:"+str(mse_train))
mse_test=mean_squared_error(mod.predict(X_test),y_test)
print("MSE test:"+str(mse_test))
# Out:
# MSE train:221822513745.05777
# MSE test:199641806867.85773

# %% [markdown]
# ## Regresión lineal múltiple

# %%
covs=["gross.square.feet","age","land.square.feet"]
X_train=df_train[covs].copy()
X_test=df_test[covs].copy()
mod=LinearRegression()
mod.fit(X_train,y_train)
# Mostramos los coeficientes
lis_coef=[[mod.intercept_],mod.coef_[0]]

# %% [markdown]
# Vemos además que aumenta aún más el valor de $R^2$ y se reduce el MSE:

# %%
print(mod.score(X_train,y_train))
print(mod.score(X_test,y_test))
# Out:
# 0.2731121187774799
# 0.2645867018733289

# %%
mse_train=mean_squared_error(mod.predict(X_train),y_train)
print("MSE train:"+str(mse_train))
mse_test=mean_squared_error(mod.predict(X_test),y_test)
print("MSE test:"+str(mse_test))
# Out:
# MSE train:216273589297.36288
# MSE test:196498296118.1105

# %% [markdown]
# ### Evaluación gráfica
# A diferencia de los casos anteriores, ahora se agrega una complejidad. Como las variables agregadas no tienen necesariamente relación con la superficie del inmueble, puede ocurrir lo siguiente: para dos inmuebles de igual superficie, pero distinta antigüedad por ejemplo, los precios de venta estimados pueden diferir.
#
# Por lo tanto, ya no sirve sobreponer una única curva sobre los datos originales ya que las predicciones pueden no estar necesariamente conectadas entre sí. Además, tiene que estar la opción de agregar predicciones para **todas** las combinaciones posibles de las tres variables involucradas.
#
# Por lo tanto, en vez de predecir algunos valores representativos, vamos a predecir **todos** los datos originales. Es decir, las variables que usamos para predecir las aplicamos en todas las instancias (sin repetición de combinaciones):

# %%
# Entrenamiento
df_pred=X_train.drop_duplicates().copy()
df_pred["sale.price"]=mod.predict(df_pred)
sns.scatterplot(data=df_train,x="gross.square.feet",y=y_train,alpha=0.4)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price",color="red",alpha=0.5,marker="x",s=100)
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %%
# Testeo
df_pred=X_test.drop_duplicates().copy()
df_pred["sale.price"]=mod.predict(df_pred)
sns.scatterplot(data=df_test,x="gross.square.feet",y=y_test,alpha=0.4)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price",color="red",alpha=0.5,marker="x",s=100)
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %% [markdown]
# Notemos que en este caso, las estimaciones no están todas sobre la misma curva. Sobre todo en el medio, los puntos aparecen a distintas alturas para iguales valores de $x$. Justamente, esto se debe a que entran en juego las otras variables no disponibles en el gráfico (antigüedad y superficie del lote). Distintos valores de estas dos variables proveen distintas estimaciones y por lo tanto, tienen una "coordenada y" diferente.
#
# Por otro lado, vale remarcar que esta variabilidad de las estimaciones también explica el incremento de $R^2$ con este modelo, ya que al tener más factores en cuenta, las estimaciones se pueden adaptar más a la heterogeneidad de los datos.

# %% [markdown]
# ## Variables categóricas
#
# Hay un factor que no fue considerado en el modelo anterior que es de suma importancia en el mercado inmobiliario: la **ubicación** del inmueble.
#
# Sin embargo, surgen los siguientes inconvenientes:
# * Al ser una variable categórica, ¿Cómo se "suma un distrito" numéricamente?
# * Para "sumar" los valores de la variable "distrito", se puede establecer un código numérico para cada distrito (Distrito 1, Distrito 2, etc.). Sin embargo, este orden establecido es completamente arbitrario, podrían intercambiarse los valores (por ejemplo, puede cambiarse el Distrito 1, por el Distrito 2 y viceversa) y alterar todas las sumas que quisimos hacer previamente.
#
# Por lo tanto, hay que tener cierto cuidado a la hora de incluir variables categóricas en un modelo de regresión.

# %% [markdown]
# ## Gráfico exploratorio
#
# Primero inspeccionemos cómo son los precios de venta respecto de las superficies en cada distrito:

# %%
g=sns.relplot(x="gross.square.feet", y="sale.price", data=df, kind="scatter",
col="borough",col_wrap=3)
g.set(xlabel="Superficie [Pies^2]",ylabel="Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %% [markdown]
# ## Variables dummies
#
# Para utilizar un criterio coherente, se crea una columna por cada nivel de la variable categórica que se quiere utilizar. Estas columnas agregadas se llaman "variables dummies" y sólo toman dos valores: 1 y 0. En python, se genera con el método "get_dummies".

# %%
# Creamos una nueva base df1 con las variables dummies para la variable "borough"
df1_train=pd.get_dummies(df_train,columns=["borough"])
df1_test=pd.get_dummies(df_test,columns=["borough"])
# Mostramos los nombres de las columnas de la base original y en la base nueva
print("Columnas base original:")
print(df_train.columns.values)
print("Columnas base nueva:")
print(df1_train.columns.values)
# Out:
# Columnas base original:
# ['time.index' 'borough' 'neighborhood' 'building.class.category'
#  'zip.code' 'residential.units' 'commercial.units' 'total.units'
#  'land.square.feet' 'gross.square.feet' 'year.built' 'sale.date'
#  'sale.year' 'age']
# Columnas base nueva:
# ['time.index' 'neighborhood' 'building.class.category' 'zip.code'
#  'residential.units' 'commercial.units' 'total.units' 'land.square.feet'
#  'gross.square.feet' 'year.built' 'sale.date' 'sale.year' 'age'
#  'borough_1' 'borough_2' 'borough_3' 'borough_4' 'borough_5']

# %% [markdown]
# Se ve que en la nueva base desaparece la variable `'borough'` y aparecen 5 nuevas variables: `'borough_1',
#  'borough_2', 'borough_3', 'borough_4', 'borough_5'`. Es decir, se eliminó una columna pero se agregaron otras 5.
#
# Veamos cómo se genera esta transformación y cómo se codifica la información:

# %%
print("Base original:")
print(df_train[["borough","neighborhood"]].head())
covsB=[dV for dV in df1_train.columns.values if dV.startswith("borough_")]
print("Base con dummies:")
print(df1_train[covsB].head())
# Out:
# Base original:
#        borough      neighborhood
# 3113         3    SHEEPSHEAD BAY
# 6152         4         LAURELTON
# 1814         3     EAST NEW YORK
# 11276        5  NEW DORP-HEIGHTS
# 12234        5       TOTTENVILLE
# Base con dummies:
#        borough_1  borough_2  borough_3  borough_4  borough_5
# 3113       False      False       True      False      False
# 6152       False      False      False       True      False
# 1814       False      False       True      False      False
# 11276      False      False      False      False       True
# 12234      False      False      False      False       True

# %% [markdown]
# Se puede ver que los inmuebles que pertenecen al distrito 5, tienen en la columna `'borough_5'` un 1 y un cero en las otras columnas. Del mismo modo, el inmueble que pertenece al distrito 4, tiene un 1 en la columna `'borough_4'` y un cero en las otras columnas. Lo mismo sucede con las observaciones de otro distrito. Es decir, se utilizan las columnas para saber a qué categoría pertenece.
#
# Notar además, que todas las categorías presentan el mismo valor y por lo tanto, no se generan diferencias numéricas entre las mismas.

# %% [markdown]
# ## Estimación
#
# Para generar estas rectas específicas por distrito, debemos basarnos en las variables dummies, generando otras columnas multiplicando por la variable de superficie.

# %%
# Los nombres de las variables dummies
covsB=[dV for dV in df1_train.columns.values if dV.startswith("borough_")]
# Los nombres de las nuevas variables de superficie multiplicadas por las variables dummies
covsBgsf=[dV+"_gsf" for dV in covsB]
for i in range(5):
  df1_train[covsBgsf[i]]=df1_train[covsB[i]]*df1_train["gross.square.feet"]
  df1_test[covsBgsf[i]]=df1_test[covsB[i]]*df1_test["gross.square.feet"]

# %% [markdown]
# Vemos que estas nuevas columnas guardan la información por distrito:

# %%
covsB=[dV for dV in df1_train.columns.values if dV.startswith("borough_")]
print("Datos originales de superficie:")
print(df_train[["borough","gross.square.feet"]].head())
print("Datos nuevos de superficie:")
print(df1_train[covsB].head())
# Out:
# Datos originales de superficie:
#        borough  gross.square.feet
# 3113         3                548
# 6152         4               1091
# 1814         3               1080
# 11276        5               1663
# 12234        5               1300
# Datos nuevos de superficie:
#        borough_1  borough_2  borough_3  borough_4  borough_5  borough_1_gsf  \
# 3113       False      False       True      False      False              0
# 6152       False      False      False       True      False              0
# 1814       False      False       True      False      False              0
# 11276      False      False      False      False       True              0
# 12234      False      False      False      False       True              0
#
#        borough_2_gsf  borough_3_gsf  borough_4_gsf  borough_5_gsf
# 3113               0            548              0              0
# 6152               0              0           1091              0
# 1814               0           1080              0              0
# 11276              0              0              0           1663
# 12234              0              0              0           1300

# %% [markdown]
# Notar que para los inmuebles del distrito 5, se obtienen valores distinto de cero en las columnas correspondientes al distrito 5. Más aún, la variable `'borough_5_gsf'` contiene los valores correspondientes a la superficie de cada inmueble de dicho distrito. Lo mismo ocurre con el resto de los distritos.
#
# Con estas nuevas variables, podemos generar el modelo deseado:

# %%
X_train=df1_train[covsB].copy()
X_test=df1_test[covsB].copy()
mod=LinearRegression(fit_intercept=False)
mod.fit(X_train,y_train)
# Out:
# LinearRegression(fit_intercept=False)

# %% [markdown]
# ### Evaluación del modelo
#
# Aunque no llega a valores muy altos, vemos que el $R^2$ aumenta considerablemente respecto de los modelos anteriores. Esto se da porque las predicciones se adaptan mejor a la heterogeneidad de los datos. Para verlo gráficamente, primero agregamos las predicciones como filas de la base para que sea más fácil ordenarlos por distrito.

# %%
print(mod.score(X_train,y_train))
print(mod.score(X_test,y_test))
# Out:
# 0.48652296433220055
# 0.43117854185417837

# %%
mse_train=mean_squared_error(mod.predict(X_train),y_train)
print("MSE train:"+str(mse_train))
mse_test=mean_squared_error(mod.predict(X_test),y_test)
print("MSE test:"+str(mse_test))
# Out:
# MSE train:152776685915.95233
# MSE test:151985893654.34732

# %% [markdown]
# ### Evaluación gráfica
#
# Con esta base podemos ver las estimaciones por distrito. Se ve cómo fueron adaptadas distintas rectas para cada distrito.

# %%
# Agrego una columna que describa el distrito para poder luego separar los gráficos según esta variable.
df1_train["borough"]=df_train["borough"].copy()
df1_train["sale.price"]=y_train.copy()
df1_test["borough"]=df_test["borough"].copy()
df1_test["sale.price"]=y_test.copy()
# De todas las variables de la base, sólo se requieren las siguientes para realizar las predicciones
vars=['gross.square.feet','borough_1','borough_2', 'borough_3', 'borough_4', 'borough_5',
       'borough_1_gsf', 'borough_2_gsf', 'borough_3_gsf', 'borough_4_gsf','borough_5_gsf', 'borough','sale.price']
# En la base nueva sólo me quedo con las variables seleccionadas
df1_train=df1_train[vars]
df1_test=df1_test[vars]
# La cantidad de variables generadas
nVars=len(vars)
# Agrego una columna para identificar a los datos observados
df1_train["clase"]=["Reales"]*df1_train.shape[0]
df1_test["clase"]=["Reales"]*df1_test.shape[0]
# Considero un vector entre el máximo y el mínimo de las superficies para graficar las predicciones
minX=df1_train["gross.square.feet"].min()
maxX=df1_train["gross.square.feet"].max()
xS=np.linspace(minX,maxX,100)
minX_test=df1_test["gross.square.feet"].min()
maxX_test=df1_test["gross.square.feet"].max()
xS_test=np.linspace(minX,maxX,100)
nS=len(xS)
# La variable "i" recorre los distritos
for i in range(1,6):
  # Inicio una base con la variable de superficie
  dfAux=pd.DataFrame({"gross.square.feet":xS})
  dfAux_test=pd.DataFrame({"gross.square.feet":xS_test})
  # La variable "j" recorre las variables correspondientes a los distritos
  for j in range(1,nVars-2):
    varAux=vars[j]
    # Si el número "i" aparece en la variable, hay un valor para imputar
    if str(i) in varAux:
      if "gsf" in varAux:
      # Si la variable tiene la combinación "gsf", es porque representa los
      # metros cuadrados de un inmueble de el distrito en cuestión
        dfAux[varAux]=dfAux["gross.square.feet"]
      else:
      # Si la variable No tiene la combinación "gsf", sólo debe imputarse un valor 1
        dfAux[varAux]=[1]*nS
    else:
      # Si la variable actual no corresponde al distrito "i", se agrega un 0
      dfAux[varAux]=[0]*nS
  # Agrego las variables que permiten igualar la base de predicciones con la base original
  dfAux["borough"]=i
  dfAux["sale.price"]=mod.predict(dfAux[covsB])
  dfAux["clase"]=["Estimados"]*nS
  # Agrego debajo de la base actual, la base con las estimaciones del distrito "i"
  df1_train=pd.concat([df1_train,dfAux])

# %%
# Entrenamiento
g=sns.relplot(x="gross.square.feet", y="sale.price", data=df1_train, kind="scatter",
col="borough",col_wrap=3,hue="clase",style="clase",markers={"Reales":"o","Estimados":"X"},palette="deep")
g.set(xlabel="Superficie [Pies^2]",ylabel="Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %%
# Testeo
g=sns.relplot(x="gross.square.feet", y=y_test, data=df1_test, kind="scatter",
col="borough",col_wrap=3,hue="clase",style="clase",markers={"Reales":"o","Estimados":"X"},palette="deep")
g.set(xlabel="Superficie [Pies^2]",ylabel="Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %% [markdown]
# ## Regularización

# %%
df1_train=pd.get_dummies(df_train,columns=["borough"])
df1_test=pd.get_dummies(df_test,columns=["borough"])
covsB=[dV for dV in df1_train.columns.values if dV.startswith("borough_")]
covsBgsf=[dV+"_gsf" for dV in covsB]
covsBlsf=[dV+"_lsf" for dV in covsB]
covsBage=[dV+"_age" for dV in covsB]
covsBrUn=[dV+"_rUn" for dV in covsB]
covsBcUn=[dV+"_cUn" for dV in covsB]
for i in range(5):
  df1_train[covsBgsf[i]]=df1_train[covsB[i]]*df1_train["gross.square.feet"]
  df1_test[covsBgsf[i]]=df1_test[covsB[i]]*df1_test["gross.square.feet"]
  df1_train[covsBlsf[i]]=df1_train[covsB[i]]*df1_train["land.square.feet"]
  df1_train[covsBage[i]]=df1_train[covsB[i]]*df1_train["age"]
  df1_train[covsBrUn[i]]=df1_train[covsB[i]]*df1_train["residential.units"]
  df1_train[covsBcUn[i]]=df1_train[covsB[i]]*df1_train["commercial.units"]
  df1_test[covsBlsf[i]]=df1_test[covsB[i]]*df1_test["land.square.feet"]
  df1_test[covsBage[i]]=df1_test[covsB[i]]*df1_test["age"]
  df1_test[covsBrUn[i]]=df1_test[covsB[i]]*df1_test["residential.units"]
  df1_test[covsBcUn[i]]=df1_test[covsB[i]]*df1_test["commercial.units"]

# %%
print(df1_train.head())
print(df1_train.info())
# Out:
#        time.index      neighborhood  building.class.category  zip.code  \
# 3113           35    SHEEPSHEAD BAY  01 ONE FAMILY DWELLINGS     11235
# 6152           52         LAURELTON  01 ONE FAMILY DWELLINGS     11413
# 1814           72     EAST NEW YORK  01 ONE FAMILY DWELLINGS     11208
# 11276         346  NEW DORP-HEIGHTS  01 ONE FAMILY DWELLINGS     10306
# 12234         268       TOTTENVILLE  01 ONE FAMILY DWELLINGS     10307
#
#        residential.units  commercial.units  total.units  land.square.feet  \
# 3113                   1                 0            1              1571
# 6152                   1                 0            1              5200
# 1814                   1                 0            1              1190
# 11276                  1                 0            1              5000
# 12234                  1                 0            1              6216
#
#        gross.square.feet  year.built  ... borough_4_gsf  borough_4_lsf  \
# 3113                 548        1920  ...             0              0
# 6152                1091        1945  ...          1091           5200
# 1814                1080        1920  ...             0              0
# 11276               1663        1920  ...             0              0
# 12234               1300        1950  ...             0              0
#
#        borough_4_age  borough_4_rUn  borough_4_cUn  borough_5_gsf  \
# 3113               0              0              0              0
# 6152              73              1              0              0
# 1814               0              0              0              0
# 11276              0              0              0           1663
# 12234              0              0              0           1300
#
#        borough_5_lsf  borough_5_age  borough_5_rUn  borough_5_cUn
# 3113               0              0              0              0
# 6152               0              0              0              0
# 1814               0              0              0              0
# 11276           5000             97              1              0
# 12234           6216             67              1              0
#
# [5 rows x 43 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 8867 entries, 3113 to 8510
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   time.index               8867 non-null   int64
#  1   neighborhood             8867 non-null   object
#  2   building.class.category  8867 non-null   object
#  3   zip.code                 8867 non-null   int64
#  4   residential.units        8867 non-null   int64
#  5   commercial.units         8867 non-null   int64
#  6   total.units              8867 non-null   int64
#  7   land.square.feet         8867 non-null   int64
#  8   gross.square.feet        8867 non-null   int64
#  9   year.built               8867 non-null   int64
#  10  sale.date                8867 non-null   object
#  11  sale.year                8867 non-null   int64
#  12  age                      8867 non-null   int64
#  13  borough_1                8867 non-null   bool
#  14  borough_2                8867 non-null   bool
#  15  borough_3                8867 non-null   bool
#  16  borough_4                8867 non-null   bool
#  17  borough_5                8867 non-null   bool
#  18  borough_1_gsf            8867 non-null   int64
#  19  borough_1_lsf            8867 non-null   int64
#  20  borough_1_age            8867 non-null   int64
#  21  borough_1_rUn            8867 non-null   int64
#  22  borough_1_cUn            8867 non-null   int64
#  23  borough_2_gsf            8867 non-null   int64
#  24  borough_2_lsf            8867 non-null   int64
#  25  borough_2_age            8867 non-null   int64
#  26  borough_2_rUn            8867 non-null   int64
#  27  borough_2_cUn            8867 non-null   int64
#  28  borough_3_gsf            8867 non-null   int64
#  29  borough_3_lsf            8867 non-null   int64
#  30  borough_3_age            8867 non-null   int64
#  31  borough_3_rUn            8867 non-null   int64
#  32  borough_3_cUn            8867 non-null   int64
#  33  borough_4_gsf            8867 non-null   int64
#  34  borough_4_lsf            8867 non-null   int64
#  35  borough_4_age            8867 non-null   int64
#  36  borough_4_rUn            8867 non-null   int64
#  37  borough_4_cUn            8867 non-null   int64
#  38  borough_5_gsf            8867 non-null   int64
#  39  borough_5_lsf            8867 non-null   int64
#  40  borough_5_age            8867 non-null   int64
#  41  borough_5_rUn            8867 non-null   int64
#  42  borough_5_cUn            8867 non-null   int64
# dtypes: bool(5), int64(35), object(3)
# memory usage: 2.7+ MB
# None

# %% [markdown]
# ## Regresión lineal múltiple
#
# Para comparar qué sucede con la regularización, vamos a incluir todas las variables en un modelo de regresión lineal, para luego regularizarlo.

# %%
df1_train.columns.values
# Out:
# array(['time.index', 'neighborhood', 'building.class.category',
#        'zip.code', 'residential.units', 'commercial.units', 'total.units',
#        'land.square.feet', 'gross.square.feet', 'year.built', 'sale.date',
#        'sale.year', 'age', 'borough_1', 'borough_2', 'borough_3',
#        'borough_4', 'borough_5', 'borough_1_gsf', 'borough_1_lsf',
#        'borough_1_age', 'borough_1_rUn', 'borough_1_cUn', 'borough_2_gsf',
#        'borough_2_lsf', 'borough_2_age', 'borough_2_rUn', 'borough_2_cUn',
#        'borough_3_gsf', 'borough_3_lsf', 'borough_3_age', 'borough_3_rUn',
#        'borough_3_cUn', 'borough_4_gsf', 'borough_4_lsf', 'borough_4_age',
#        'borough_4_rUn', 'borough_4_cUn', 'borough_5_gsf', 'borough_5_lsf',
#        'borough_5_age', 'borough_5_rUn', 'borough_5_cUn'], dtype=object)

# %%
covs=["zip.code","year.built","age","borough_1",
      "borough_2","borough_3","borough_4","borough_5","borough_1_gsf","borough_2_gsf",
      "borough_3_gsf","borough_4_gsf","borough_5_gsf",'borough_1_lsf', 'borough_1_age', 'borough_1_rUn', 'borough_1_cUn',
       'borough_2_lsf', 'borough_2_age', 'borough_2_rUn', 'borough_2_cUn',
       'borough_3_lsf', 'borough_3_age', 'borough_3_rUn', 'borough_3_cUn',
       'borough_4_lsf', 'borough_4_age', 'borough_4_rUn', 'borough_4_cUn',
       'borough_5_lsf', 'borough_5_age', 'borough_5_rUn', 'borough_5_cUn']
mod_lin = LinearRegression(fit_intercept=False)
mod_lin.fit(df1_train[covs], y_train)
y_train_pred = mod_lin.predict(df1_train[covs])
y_test_pred = mod_lin.predict(df1_test[covs])

# %% [markdown]
# Vemos la diferencia entre el entrenamiento y el testeo que es el siguiente:

# %%
from sklearn.metrics import root_mean_squared_error
rmse_lin_train=root_mean_squared_error(y_train,y_train_pred)
print("RMSE train:"+str(rmse_lin_train))
rmse_lin_test=root_mean_squared_error(y_test,y_test_pred)
print("RMSE test:"+str(rmse_lin_test))
# Out:
# RMSE train:378460.75239331665
# RMSE test:447172.0616789113

# %% [markdown]
# Por empezar, buscar el parámetro de regularización puede ser una tarea muy dificultosa ya que un cambio muy pequeño en la penalización puede generar cambios muy abruptos en las métricas obtenidas. Por lo tanto, siempre es conveniente iniciar el análisis de la regularización en un espacio logarítmico.
#
# Esto se obtiene con la función `logspace` que genera datos en un rango en el que las diferencias entre los logaritmos es equidistante.

# %%
import numpy as np


x=np.logspace(1,5,6)
print(x)
# Diferencias de x
print(np.diff(x))
# Diferencias de logaritmos de x
np.diff(np.log(x))
# Out:
# [1.00000000e+01 6.30957344e+01 3.98107171e+02 2.51188643e+03
#  1.58489319e+04 1.00000000e+05]
# [5.30957344e+01 3.35011436e+02 2.11377926e+03 1.33370455e+04
#  8.41510681e+04]
# array([1.84206807, 1.84206807, 1.84206807, 1.84206807, 1.84206807])

# %% [markdown]
# ## Ridge
#
# La regresión ridge usa una penalización en la función de costos para que los coeficientes no puedan ser tan grandes que en general pueden asociarse al overfitting.
#
# Por lo tanto, la función de costos que se usa en la regresión ridge es la siguiente:
# $$C_{\lambda}(\vec{\beta})=\sum_{i=1}^n (y_i-\beta_1\cdot x_{i,1}-\beta_2\cdot x_{i,2}-\cdots -\beta_p\cdot x_{i,p})^2+\lambda \sum_{j=1} \beta_j^2$$
#
# Donde $\lambda>0 $ se define de antemano. El problema es que es muy difícil antes de conocer los coeficientes cuál es el mejor valor para $\lambda$. No sólo eso, como los coeficientes pueden dar muy grandes, $\lambda$ puede ser un valor muy chico o muy grande para que la penalización de valores razonables. Por lo tanto, probaremos correr el algoritmo con $\lambda$ en una escala logarítmica.

# %%
def regul_coefs(df_train,y_train,eMin,eMax,nExp,covs,Lasso=False):
  alphas = np.logspace(eMin, eMax, nExp)
  df_coef=pd.DataFrame({"Variable":covs})
  if Lasso:
    from sklearn.linear_model import Lasso
    modelo_temp = Lasso(alpha=alphas[0],fit_intercept=False)
    modelo_temp.fit(df_train[covs], y_train)
  else:
    from sklearn.linear_model import Ridge
    modelo_temp = Ridge(alpha=alphas[0],fit_intercept=False)
    modelo_temp.fit(df_train[covs], y_train)
  df_coef["Coeficientes"]=modelo_temp.coef_.flatten()
  df_coef["alpha"]=alphas[0]
  for alpha in alphas[1:]:
    df_coef_Aux=pd.DataFrame({"Variable":covs})
    if Lasso:
      modelo_temp = Lasso(alpha=alpha,fit_intercept=False)
      modelo_temp.fit(df_train[covs], y_train)
    else:
      modelo_temp = Ridge(alpha=alpha,fit_intercept=False)
      modelo_temp.fit(df_train[covs], y_train)
    df_coef_Aux["Coeficientes"]=modelo_temp.coef_.flatten()
    df_coef_Aux["alpha"]=alpha
    df_coef=pd.concat([df_coef,df_coef_Aux])
  return df_coef

# %%
def regul_rmse(df_train,df_test,y_train,y_test,eMin,eMax,nExp,covs,Lasso=False):
  alphas = np.logspace(eMin, eMax, nExp)
  if Lasso:
    from sklearn.linear_model import Lasso
    modelo_temp = Lasso(alpha=alphas[0],fit_intercept=False)
    modelo_temp.fit(df_train[covs], y_train)
  else:
    from sklearn.linear_model import Ridge
    modelo_temp = Ridge(alpha=alphas[0],fit_intercept=False)
    modelo_temp.fit(df_train[covs], y_train)
  y_pred_train = modelo_temp.predict(df_train[covs])
  rmse_train = root_mean_squared_error(y_train, y_pred_train)
  y_pred_test = modelo_temp.predict(df_test[covs])
  rmse_test = root_mean_squared_error(y_test, y_pred_test)
  indAux=0
  df_rmse=pd.DataFrame({"alpha":alphas[0],"rmse_train":rmse_train,"rmse_test":rmse_test},index=[indAux])
  for alpha in alphas[1:]:
    indAux=indAux+1
    if Lasso:
      modelo_temp = Lasso(alpha=alpha,fit_intercept=False)
      modelo_temp.fit(df_train[covs], y_train)
    else:
      modelo_temp = Ridge(alpha=alpha,fit_intercept=False)
      modelo_temp.fit(df_train[covs], y_train)
    y_pred_train = modelo_temp.predict(df_train[covs])
    rmse_train = root_mean_squared_error(y_train, y_pred_train)
    y_pred_test = modelo_temp.predict(df_test[covs])
    rmse_test = root_mean_squared_error(y_test, y_pred_test)
    df_rmse_Aux=pd.DataFrame({"alpha":alpha,"rmse_train":rmse_train,"rmse_test":rmse_test},index=[indAux])
    df_rmse=pd.concat([df_rmse,df_rmse_Aux])
  return df_rmse

# %%
df_coef_ridge=regul_coefs(df_train=df1_train,y_train=y_train,eMin=-1,eMax=5,nExp=400,covs=covs)

# %%
sns.lineplot(data=df_coef_ridge,x="alpha",y="Coeficientes",hue="Variable")
sns.color_palette("hls", 18)
plt.legend(bbox_to_anchor=(1.5, 1), borderaxespad=0)
plt.xscale('log')
plt.show()

# %% [markdown]
# ### Valores de los coeficientes

# %%
from sklearn.linear_model import Ridge
alpha_prueba=1
mod_prueba = Ridge(alpha=alpha_prueba,fit_intercept=False)
mod_prueba.fit(df1_train[covs], y_train)
print("coeficientes:")
print(list(zip(covs,mod_prueba.coef_)))
max_prueba=mod_prueba.coef_.max()
var_max_prueba=np.argmax(mod_prueba.coef_)
min_prueba=mod_prueba.coef_.min()
var_min_prueba=np.argmin(mod_prueba.coef_)
print("Máximo:"+ str(max_prueba)," - Variable:"+ covs[var_max_prueba])
print("Mínimo:"+ str(min_prueba)," - Variable:"+ covs[var_min_prueba])
# Out:
# coeficientes:
# [('zip.code', np.float64(-157.83966841738913)), ('year.built', np.float64(822.4584617689574)), ('age', np.float64(3767.1264660966617)), ('borough_1', np.float64(-187657.57373289476)), ('borough_2', np.float64(390973.0594271506)), ('borough_3', np.float64(-555413.0593203328)), ('borough_4', np.float64(239543.80604033193)), ('borough_5', np.float64(98552.01804595468)), ('borough_1_gsf', np.float64(1065.8567224102446)), ('borough_2_gsf', np.float64(108.67914593463456)), ('borough_3_gsf', np.float64(798.6280907842473)), ('borough_4_gsf', np.float64(238.91999179798776)), ('borough_5_gsf', np.float64(145.96445761244075)), ('borough_1_lsf', np.float64(-774.8024279996872)), ('borough_1_age', np.float64(17047.02198265008)), ('borough_1_rUn', np.float64(-187657.57373291074)), ('borough_1_cUn', np.float64(165488.25373872212)), ('borough_2_lsf', np.float64(72.60966625497362)), ('borough_2_age', np.float64(-4152.250839440318)), ('borough_2_rUn', np.float64(-226763.20688978097)), ('borough_2_cUn', np.float64(311185.259347003)), ('borough_3_lsf', np.float64(-42.087407242990984)), ('borough_3_age', np.float64(-83.03102112723158)), ('borough_3_rUn', np.float64(172935.09340952677)), ('borough_3_cUn', np.float64(-353721.6442401049)), ('borough_4_lsf', np.float64(46.434032280989754)), ('borough_4_age', np.float64(-4929.241885924297)), ('borough_4_rUn', np.float64(207377.5551667146)), ('borough_4_cUn', np.float64(-19832.213814254083)), ('borough_5_lsf', np.float64(36.07269152797047)), ('borough_5_age', np.float64(-4115.371755731347)), ('borough_5_rUn', np.float64(98552.01804608607)), ('borough_5_cUn', np.float64(-131858.09814342487))]
# Máximo:390973.0594271506  - Variable:borough_2
# Mínimo:-555413.0593203328  - Variable:borough_3

# %%
alpha_prueba=10**2
mod_prueba = Ridge(alpha=alpha_prueba,fit_intercept=False)
mod_prueba.fit(df1_train[covs], y_train)
print("coeficientes:")
print(list(zip(covs,mod_prueba.coef_)))
max_prueba=mod_prueba.coef_.max()
var_max_prueba=np.argmax(mod_prueba.coef_)
min_prueba=mod_prueba.coef_.min()
var_min_prueba=np.argmin(mod_prueba.coef_)
print("Máximo:"+ str(max_prueba)," - Variable:"+ covs[var_max_prueba])
print("Mínimo:"+ str(min_prueba)," - Variable:"+ covs[var_min_prueba])
# Out:
# coeficientes:
# [('zip.code', np.float64(-175.8306491298763)), ('year.built', np.float64(976.3046532254764)), ('age', np.float64(3139.6500344920983)), ('borough_1', np.float64(-1938.6197837824534)), ('borough_2', np.float64(12903.150878180297)), ('borough_3', np.float64(-153933.2452480427)), ('borough_4', np.float64(112127.50712623022)), ('borough_5', np.float64(30704.012354514838)), ('borough_1_gsf', np.float64(1079.1233628613036)), ('borough_2_gsf', np.float64(135.61524332420746)), ('borough_3_gsf', np.float64(753.986299125144)), ('borough_4_gsf', np.float64(255.24171165943923)), ('borough_5_gsf', np.float64(149.93042932559752)), ('borough_1_lsf', np.float64(-799.6322304394192)), ('borough_1_age', np.float64(13486.170514470341)), ('borough_1_rUn', np.float64(-1938.6197837826967)), ('borough_1_cUn', np.float64(8603.961702466275)), ('borough_2_lsf', np.float64(65.5488895846394)), ('borough_2_age', np.float64(-3111.2175917950613)), ('borough_2_rUn', np.float64(-12246.632768023981)), ('borough_2_cUn', np.float64(38005.75906106367)), ('borough_3_lsf', np.float64(-44.26969420094383)), ('borough_3_age', np.float64(-729.2006835924464)), ('borough_3_rUn', np.float64(-135266.40027527921)), ('borough_3_cUn', np.float64(-132213.69343289273)), ('borough_4_lsf', np.float64(49.126719786678464)), ('borough_4_age', np.float64(-3233.173444368151)), ('borough_4_rUn', np.float64(120686.87598912421)), ('borough_4_cUn', np.float64(-9349.725430119843)), ('borough_5_lsf', np.float64(36.03642626112747)), ('borough_5_age', np.float64(-3272.928759808607)), ('borough_5_rUn', np.float64(30704.012354516155)), ('borough_5_cUn', np.float64(-16758.207697972714))]
# Máximo:120686.87598912421  - Variable:borough_4_rUn
# Mínimo:-153933.2452480427  - Variable:borough_3

# %%
alpha_prueba=10**15
mod_prueba = Ridge(alpha=alpha_prueba,fit_intercept=False)
mod_prueba.fit(df1_train[covs], y_train)
print("coeficientes:")
print(list(zip(covs,mod_prueba.coef_)))
max_prueba=mod_prueba.coef_.max()
var_max_prueba=np.argmax(mod_prueba.coef_)
min_prueba=mod_prueba.coef_.min()
var_min_prueba=np.argmin(mod_prueba.coef_)
print("Máximo:"+ str(max_prueba)," - Variable:"+ covs[var_max_prueba])
print("Mínimo:"+ str(min_prueba)," - Variable:"+ covs[var_min_prueba])
# Out:
# coeficientes:
# [('zip.code', np.float64(0.06491720463756735)), ('year.built', np.float64(0.011426189937717908)), ('age', np.float64(0.00044598658651136063)), ('borough_1', np.float64(1.6513524488559284e-07)), ('borough_2', np.float64(3.3020771836175673e-07)), ('borough_3', np.float64(1.3889538186248754e-06)), ('borough_4', np.float64(2.767039191800438e-06)), ('borough_5', np.float64(1.2328510443657691e-06)), ('borough_1_gsf', np.float64(0.0005762988111501093)), ('borough_2_gsf', np.float64(0.0005835272702485299)), ('borough_3_gsf', np.float64(0.002797253655235149)), ('borough_4_gsf', np.float64(0.0043404091033981676)), ('borough_5_gsf', np.float64(0.0020554170932899633)), ('borough_1_lsf', np.float64(0.0002555747613343898)), ('borough_1_age', np.float64(1.8717866429072443e-05)), ('borough_1_rUn', np.float64(1.651352448855929e-07)), ('borough_1_cUn', np.float64(1.95027333165897e-08)), ('borough_2_lsf', np.float64(0.0011744798691460286)), ('borough_2_age', np.float64(2.629557421325829e-05)), ('borough_2_rUn', np.float64(3.331048359248823e-07)), ('borough_2_cUn', np.float64(1.1336890218710189e-08)), ('borough_3_lsf', np.float64(0.0035913526404933445)), ('borough_3_age', np.float64(0.00012338174685967314)), ('borough_3_rUn', np.float64(1.395179510877186e-06)), ('borough_3_cUn', np.float64(8.098206942589747e-08)), ('borough_4_lsf', np.float64(0.01002363446367089)), ('borough_4_age', np.float64(0.00021826712117747264)), ('borough_4_rUn', np.float64(2.7757059144682915e-06)), ('borough_4_cUn', np.float64(3.1452210467845304e-08)), ('borough_5_lsf', np.float64(0.005405669285875912)), ('borough_5_age', np.float64(5.9324277831883954e-05)), ('borough_5_rUn', np.float64(1.23285104436577e-06)), ('borough_5_cUn', np.float64(6.6551715400633704e-09))]
# Máximo:0.06491720463756735  - Variable:zip.code
# Mínimo:6.6551715400633704e-09  - Variable:borough_5_cUn

# %% [markdown]
# ## Selección del hiperparámetro

# %%
df_rmse_ridge=regul_rmse(df_train=df1_train,df_test=df1_test,y_train=y_train,y_test=y_test,eMin=-4,eMax=5,nExp=400,covs=covs)
# Out:
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.75603e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.0629e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.38608e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.72649e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.08499e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.46269e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.86032e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.27945e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.72077e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.18554e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.67521e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.0191e-16): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.0734e-16): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)

# %%
df_rmse_ridge.head()
# Out:
#       alpha     rmse_train      rmse_test
# 0  0.000100  378472.279200  404236.073813
# 1  0.000105  378472.958678  403294.871463
# 2  0.000111  378473.660929  402368.384748
# 3  0.000117  378474.385259  401458.203704
# 4  0.000123  378475.130857  400565.832725

# %%
rango_alpha=df_rmse_ridge["alpha"]>0
plt.plot(df_rmse_ridge["alpha"].loc[rango_alpha],df_rmse_ridge["rmse_train"].loc[rango_alpha],c="b")
plt.plot(df_rmse_ridge["alpha"].loc[rango_alpha],df_rmse_ridge["rmse_test"].loc[rango_alpha],c="r")
plt.xlabel("Alpha")
plt.ylabel("RMSE")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
rango_alpha=df_rmse_ridge["alpha"]>0
id_optimo=df_rmse_ridge["rmse_test"].loc[rango_alpha].idxmin()
alpha_optimo=df_rmse_ridge["alpha"].iloc[id_optimo]

# %%
plt.plot(df_rmse_ridge["alpha"].loc[rango_alpha],df_rmse_ridge["rmse_train"].loc[rango_alpha],c="b")
plt.plot(df_rmse_ridge["alpha"].loc[rango_alpha],df_rmse_ridge["rmse_test"].loc[rango_alpha],c="r")
plt.axvline(
    x=alpha_optimo,
    c="gray",
    linestyle='--',
    label='óptimo'
)
plt.legend(loc='upper center')
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
mod_opt = Ridge(alpha=alpha_optimo,fit_intercept=False)
mod_opt.fit(df1_train[covs], y_train)
y_train_pred = mod_opt.predict(df1_train[covs])
y_test_pred = mod_opt.predict(df1_test[covs])

# %%
print("RMSE train (Lineal):"+str(rmse_lin_train))
print("RMSE test (Lineal):"+str(rmse_lin_test))
print("Diferencia (Lineal):"+str(rmse_lin_train-rmse_lin_test))
rmse_rid_train=root_mean_squared_error(y_train,y_train_pred)
print("RMSE train (Ridge):"+str(rmse_rid_train))
rmse_rid_test=root_mean_squared_error(y_test,y_test_pred)
print("RMSE test (Ridge):"+str(rmse_rid_test))
print("Diferencia (Ridge):"+str(rmse_rid_train-rmse_rid_test))
# Out:
# RMSE train (Lineal):378460.75239331665
# RMSE test (Lineal):447172.0616789113
# Diferencia (Lineal):-68711.30928559467
# RMSE train (Ridge):379048.72161377576
# RMSE test (Ridge):382049.0811143976
# Diferencia (Ridge):-3000.359500621853

# %%
# Entrenamiento
df_pred=df1_train[covs].drop_duplicates().copy()
y1_pred_lm=mod_lin.predict(df_pred)
y1_pred_ridge=mod_opt.predict(df_pred)
df_pred["sale.price_lm"]=y1_pred_lm
df_pred["sale.price_ridge"]=y1_pred_ridge
sns.scatterplot(data=df1_train,x="gross.square.feet",y=y_train,alpha=0.4)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_ridge",color="red",alpha=0.5,marker="x",s=100)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_lm",color="green",alpha=0.5,marker="x",s=100)
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_8391/1058497183.py in <cell line: 0>()
#       6 df_pred["sale.price_ridge"]=y1_pred_ridge
#       7 sns.scatterplot(data=df1_train,x="gross.square.feet",y=y_train,alpha=0.4)
# ----> 8 sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_ridge",color="red",alpha=0.5,marker="x",s=100)
#       9 sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_lm",color="green",alpha=0.5,marker="x",s=100)
#      10 plt.xlabel("Superficie [Pies^2]")
#
# /usr/local/lib/python3.12/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     613 ):
#     614
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#
# /usr/local/lib/python3.12/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     394         )
#     395
# --> 396         super().__init__(data=data, variables=variables)
#     397
#     398         self.legend = legend
#
# /usr/local/lib/python3.12/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.12/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.12/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      56
#      57         data = handle_data_source(data)
# ---> 58         frame, names, ids = self._assign_variables(data, variables)
#      59
#      60         self.frame = frame
#
# /usr/local/lib/python3.12/dist-packages/seaborn/_core/data.py in _assign_variables(self, data, variables)
#     230                 else:
#     231                     err += "An entry with this name does not appear in `data`."
# --> 232                 raise ValueError(err)
#     233
#     234             else:
#
# ValueError: Could not interpret value `gross.square.feet` for `x`. An entry with this name does not appear in `data`.

# %%
# Testeo
df_pred=df1_test[covs].drop_duplicates().copy()
y1_pred_lm=mod_lin.predict(df_pred)
y1_pred_ridge=mod_opt.predict(df_pred)
df_pred["sale.price_lm"]=y1_pred_lm
df_pred["sale.price_ridge"]=y1_pred_ridge
sns.scatterplot(data=df1_test,x="gross.square.feet",y=y_test,alpha=0.4)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_ridge",color="red",alpha=0.5,marker="x",s=100)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_lm",color="green",alpha=0.5,marker="x",s=100)
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %% [markdown]
# ## LASSO
#
# La regresión Lasso usa otra penalización en la función de costos:
# $$C_{\lambda}(\vec{\beta})=\sum_{i=1}^n (y_i-\beta_1\cdot x_{i,1}-\beta_2\cdot x_{i,2}-\cdots -\beta_p\cdot x_{i,p})^2+\lambda \sum_{j=1} |\beta_j|$$

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
df_coef_lasso=regul_coefs(df_train=df1_train,y_train=y_train,eMin=-4,eMax=6,nExp=400,covs=covs,Lasso=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.434e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.423e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.411e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.398e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.385e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.370e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.355e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.340e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.323e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.306e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.287e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.268e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.248e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.226e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.181e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.152e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.121e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.088e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.046e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.001e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.953e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.902e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.848e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.790e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.728e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.663e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.593e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.517e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.345e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.248e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.142e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.027e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.901e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.764e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.612e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.446e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.262e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.059e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.834e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.584e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.304e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.992e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.642e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.250e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
sns.lineplot(data=df_coef_lasso,x="alpha",y="Coeficientes",hue="Variable")
sns.color_palette("hls", 18)
plt.legend(bbox_to_anchor=(1.5, 1), borderaxespad=0)
plt.xscale('log')
plt.show()

# %%
from sklearn.linear_model import Lasso
alpha_prueba=10**3
mod_prueba = Lasso(alpha=alpha_prueba,fit_intercept=False)
mod_prueba.fit(df1_train[covs], y_train)
print("coeficientes:")
print(list(zip(covs,mod_prueba.coef_)))
max_prueba=mod_prueba.coef_.max()
var_max_prueba=np.argmax(mod_prueba.coef_)
min_prueba=mod_prueba.coef_.min()
var_min_prueba=np.argmin(mod_prueba.coef_)
print("Máximo:"+ str(max_prueba)," - Variable:"+ covs[var_max_prueba])
print("Mínimo:"+ str(min_prueba)," - Variable:"+ covs[var_min_prueba])
# Out:
# coeficientes:
# [('zip.code', np.float64(-5.736849233104439)), ('year.built', np.float64(138.0609579624866)), ('age', np.float64(4874.38023105967)), ('borough_1', np.float64(-0.0)), ('borough_2', np.float64(-0.0)), ('borough_3', np.float64(-596046.5874818274)), ('borough_4', np.float64(0.0)), ('borough_5', np.float64(0.0)), ('borough_1_gsf', np.float64(1087.8991045163493)), ('borough_2_gsf', np.float64(116.10456265801137)), ('borough_3_gsf', np.float64(771.7716505131774)), ('borough_4_gsf', np.float64(248.03831561130903)), ('borough_5_gsf', np.float64(149.36659284258633)), ('borough_1_lsf', np.float64(-798.3987786967976)), ('borough_1_age', np.float64(10449.362016911198)), ('borough_1_rUn', np.float64(-0.0)), ('borough_1_cUn', np.float64(0.0)), ('borough_2_lsf', np.float64(64.93665579432073)), ('borough_2_age', np.float64(-6306.370414402292)), ('borough_2_rUn', np.float64(-0.0)), ('borough_2_cUn', np.float64(0.0)), ('borough_3_lsf', np.float64(-42.4586786753716)), ('borough_3_age', np.float64(-2666.9408843382803)), ('borough_3_rUn', np.float64(-0.0)), ('borough_3_cUn', np.float64(-207626.88067126847)), ('borough_4_lsf', np.float64(48.23371336118049)), ('borough_4_age', np.float64(-6353.02700596292)), ('borough_4_rUn', np.float64(43863.4621144323)), ('borough_4_cUn', np.float64(-0.0)), ('borough_5_lsf', np.float64(36.09219520548143)), ('borough_5_age', np.float64(-5847.108531842854)), ('borough_5_rUn', np.float64(0.0)), ('borough_5_cUn', np.float64(-0.0))]
# Máximo:43863.4621144323  - Variable:borough_4_rUn
# Mínimo:-596046.5874818274  - Variable:borough_3
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.481e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ### Valores de los coeficientes

# %%
alpha_prueba=1
mod_prueba = Lasso(alpha=alpha_prueba,fit_intercept=False)
mod_prueba.fit(df1_train[covs], y_train)
print("coeficientes:")
print(list(zip(covs,mod_prueba.coef_)))
max_prueba=mod_prueba.coef_.max()
var_max_prueba=np.argmax(mod_prueba.coef_)
min_prueba=mod_prueba.coef_.min()
var_min_prueba=np.argmin(mod_prueba.coef_)
print("Máximo:"+ str(max_prueba)," - Variable:"+ covs[var_max_prueba])
print("Mínimo:"+ str(min_prueba)," - Variable:"+ covs[var_min_prueba])
# Out:
# coeficientes:
# [('zip.code', np.float64(4.027459749197375)), ('year.built', np.float64(155.11962785612351)), ('age', np.float64(3556.5133907870677)), ('borough_1', np.float64(3112565.3135020435)), ('borough_2', np.float64(121087.55666745517)), ('borough_3', np.float64(-1058961.095414097)), ('borough_4', np.float64(-202757.71935104692)), ('borough_5', np.float64(1739.102199963556)), ('borough_1_gsf', np.float64(1074.314618333687)), ('borough_2_gsf', np.float64(102.82320890395319)), ('borough_3_gsf', np.float64(800.3849271718611)), ('borough_4_gsf', np.float64(237.23957155371644)), ('borough_5_gsf', np.float64(145.92760087528978)), ('borough_1_lsf', np.float64(-729.0541997274404)), ('borough_1_age', np.float64(29376.167376767444)), ('borough_1_rUn', np.float64(-5327048.034105736)), ('borough_1_cUn', np.float64(279844.94714144967)), ('borough_2_lsf', np.float64(74.17589277756551)), ('borough_2_age', np.float64(-4687.622812700296)), ('borough_2_rUn', np.float64(-292663.54630552256)), ('borough_2_cUn', np.float64(337381.95968533674)), ('borough_3_lsf', np.float64(-42.148033419466145)), ('borough_3_age', np.float64(-479.2893714012782)), ('borough_3_rUn', np.float64(198832.1469625512)), ('borough_3_cUn', np.float64(-360033.6839070759)), ('borough_4_lsf', np.float64(46.292486890481875)), ('borough_4_age', np.float64(-5637.191512455004)), ('borough_4_rUn', np.float64(174535.81420191907)), ('borough_4_cUn', np.float64(-19198.366741733465)), ('borough_5_lsf', np.float64(36.06866556949736)), ('borough_5_age', np.float64(-4569.8229892744475)), ('borough_5_rUn', np.float64(-126675.05723037806)), ('borough_5_cUn', np.float64(-141377.6848563553))]
# Máximo:3112565.3135020435  - Variable:borough_1
# Mínimo:-5327048.034105736  - Variable:borough_1_rUn
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.375e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
alpha_prueba=10**3
mod_prueba = Lasso(alpha=alpha_prueba,fit_intercept=False)
mod_prueba.fit(df1_train[covs], y_train)
print("coeficientes:")
print(list(zip(covs,mod_prueba.coef_)))
max_prueba=mod_prueba.coef_.max()
var_max_prueba=np.argmax(mod_prueba.coef_)
min_prueba=mod_prueba.coef_.min()
var_min_prueba=np.argmin(mod_prueba.coef_)
print("Máximo:"+ str(max_prueba)," - Variable:"+ covs[var_max_prueba])
print("Mínimo:"+ str(min_prueba)," - Variable:"+ covs[var_min_prueba])
# Out:
# coeficientes:
# [('zip.code', np.float64(-5.736849233104439)), ('year.built', np.float64(138.0609579624866)), ('age', np.float64(4874.38023105967)), ('borough_1', np.float64(-0.0)), ('borough_2', np.float64(-0.0)), ('borough_3', np.float64(-596046.5874818274)), ('borough_4', np.float64(0.0)), ('borough_5', np.float64(0.0)), ('borough_1_gsf', np.float64(1087.8991045163493)), ('borough_2_gsf', np.float64(116.10456265801137)), ('borough_3_gsf', np.float64(771.7716505131774)), ('borough_4_gsf', np.float64(248.03831561130903)), ('borough_5_gsf', np.float64(149.36659284258633)), ('borough_1_lsf', np.float64(-798.3987786967976)), ('borough_1_age', np.float64(10449.362016911198)), ('borough_1_rUn', np.float64(-0.0)), ('borough_1_cUn', np.float64(0.0)), ('borough_2_lsf', np.float64(64.93665579432073)), ('borough_2_age', np.float64(-6306.370414402292)), ('borough_2_rUn', np.float64(-0.0)), ('borough_2_cUn', np.float64(0.0)), ('borough_3_lsf', np.float64(-42.4586786753716)), ('borough_3_age', np.float64(-2666.9408843382803)), ('borough_3_rUn', np.float64(-0.0)), ('borough_3_cUn', np.float64(-207626.88067126847)), ('borough_4_lsf', np.float64(48.23371336118049)), ('borough_4_age', np.float64(-6353.02700596292)), ('borough_4_rUn', np.float64(43863.4621144323)), ('borough_4_cUn', np.float64(-0.0)), ('borough_5_lsf', np.float64(36.09219520548143)), ('borough_5_age', np.float64(-5847.108531842854)), ('borough_5_rUn', np.float64(0.0)), ('borough_5_cUn', np.float64(-0.0))]
# Máximo:43863.4621144323  - Variable:borough_4_rUn
# Mínimo:-596046.5874818274  - Variable:borough_3
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.481e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
alpha_prueba=10**15
mod_prueba = Lasso(alpha=alpha_prueba,fit_intercept=False)
mod_prueba.fit(df1_train[covs], y_train)
print("coeficientes:")
print(list(zip(covs,mod_prueba.coef_)))
max_prueba=mod_prueba.coef_.max()
var_max_prueba=np.argmax(mod_prueba.coef_)
min_prueba=mod_prueba.coef_.min()
var_min_prueba=np.argmin(mod_prueba.coef_)
print("Máximo:"+ str(max_prueba)," - Variable:"+ covs[var_max_prueba])
print("Mínimo:"+ str(min_prueba)," - Variable:"+ covs[var_min_prueba])
# Out:
# coeficientes:
# [('zip.code', np.float64(0.0)), ('year.built', np.float64(0.0)), ('age', np.float64(0.0)), ('borough_1', np.float64(0.0)), ('borough_2', np.float64(0.0)), ('borough_3', np.float64(0.0)), ('borough_4', np.float64(0.0)), ('borough_5', np.float64(0.0)), ('borough_1_gsf', np.float64(0.0)), ('borough_2_gsf', np.float64(0.0)), ('borough_3_gsf', np.float64(0.0)), ('borough_4_gsf', np.float64(0.0)), ('borough_5_gsf', np.float64(0.0)), ('borough_1_lsf', np.float64(0.0)), ('borough_1_age', np.float64(0.0)), ('borough_1_rUn', np.float64(0.0)), ('borough_1_cUn', np.float64(0.0)), ('borough_2_lsf', np.float64(0.0)), ('borough_2_age', np.float64(0.0)), ('borough_2_rUn', np.float64(0.0)), ('borough_2_cUn', np.float64(0.0)), ('borough_3_lsf', np.float64(0.0)), ('borough_3_age', np.float64(0.0)), ('borough_3_rUn', np.float64(0.0)), ('borough_3_cUn', np.float64(0.0)), ('borough_4_lsf', np.float64(0.0)), ('borough_4_age', np.float64(0.0)), ('borough_4_rUn', np.float64(0.0)), ('borough_4_cUn', np.float64(0.0)), ('borough_5_lsf', np.float64(0.0)), ('borough_5_age', np.float64(0.0)), ('borough_5_rUn', np.float64(0.0)), ('borough_5_cUn', np.float64(0.0))]
# Máximo:0.0  - Variable:zip.code
# Mínimo:0.0  - Variable:zip.code

# %% [markdown]
# ### Selección del hiperparámetro

# %%
df_rmse_lasso=regul_rmse(df_train=df1_train,df_test=df1_test,y_train=y_train,y_test=y_test,eMin=-6,eMax=5,nExp=400,covs=covs,Lasso=True)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.374e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.597e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.596e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.596e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.595e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.594e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.593e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.591e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.590e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.588e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.586e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.576e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.581e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.580e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.579e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.578e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.577e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.575e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.574e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.572e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.570e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.568e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.566e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.563e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.560e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.557e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.554e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.550e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.546e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.541e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.536e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.530e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.524e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.517e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.509e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.500e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.489e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.481e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.471e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.461e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.449e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.438e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.425e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.412e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.398e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.383e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
df_rmse_lasso.head()
# Out:
#       alpha     rmse_train      rmse_test
# 0  0.000001  379163.913280  383490.526718
# 1  0.000001  379163.913280  383490.526718
# 2  0.000001  379163.913280  383490.526717
# 3  0.000001  379163.913280  383490.526716
# 4  0.000001  379163.913279  383490.526716

# %%
rango_alpha=df_rmse_lasso["alpha"]>0
plt.plot(df_rmse_lasso["alpha"].loc[rango_alpha],df_rmse_lasso["rmse_train"].loc[rango_alpha],c="b")
plt.plot(df_rmse_lasso["alpha"].loc[rango_alpha],df_rmse_lasso["rmse_test"].loc[rango_alpha],c="r")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
rango_alpha=df_rmse_lasso["alpha"]>0
id_optimo=df_rmse_lasso["rmse_test"].loc[rango_alpha].idxmin()
alpha_optimo=df_rmse_lasso["alpha"].iloc[id_optimo]
alpha_optimo
# Out:
# np.float64(514.9670581618343)

# %%
plt.plot(df_rmse_lasso["alpha"].loc[rango_alpha],df_rmse_lasso["rmse_train"].loc[rango_alpha],c="b")
plt.plot(df_rmse_lasso["alpha"].loc[rango_alpha],df_rmse_lasso["rmse_test"].loc[rango_alpha],c="r")
plt.axvline(
    x=alpha_optimo,
    c="gray",
    linestyle='--',
    label='óptimo'
)
plt.legend(loc='upper center')
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
mod_opt = Lasso(alpha=alpha_optimo,fit_intercept=False)
mod_opt.fit(df1_train[covs], y_train)
y_train_pred = mod_opt.predict(df1_train[covs])
y_test_pred = mod_opt.predict(df1_test[covs])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.441e+14, tolerance: 6.552e+11
#   model = cd_fast.enet_coordinate_descent(

# %%
print("RMSE train (Lineal):"+str(rmse_lin_train))
print("RMSE test (Lineal):"+str(rmse_lin_test))
print("Diferencia (Lineal):"+str(rmse_lin_train-rmse_lin_test))
print("RMSE train (Ridge):"+str(rmse_rid_train))
print("RMSE test (Ridge):"+str(rmse_rid_test))
print("Diferencia (Ridge):"+str(rmse_rid_train-rmse_rid_test))
rmse_lass_train=root_mean_squared_error(y_train,y_train_pred)
print("RMSE train (Lasso):"+str(rmse_lass_train))
rmse_lass_test=root_mean_squared_error(y_test,y_test_pred)
print("RMSE test (Lasso):"+str(rmse_lass_test))
print("Diferencia (Lasso):"+str(rmse_lass_train-rmse_lass_test))
# Out:
# RMSE train (Lineal):378460.75239331665
# RMSE test (Lineal):447172.0616789113
# Diferencia (Lineal):-68711.30928559467
# RMSE train (Ridge):379048.72161377576
# RMSE test (Ridge):382049.0811143976
# Diferencia (Ridge):-3000.359500621853
# RMSE train (Lasso):379776.9734730594
# RMSE test (Lasso):383175.5898479774
# Diferencia (Lasso):-3398.6163749179686

# %%
# Entrenamiento
df_pred=df1_train[covs].drop_duplicates().copy()
y1_pred_lm=mod_lin.predict(df_pred)
y1_pred_lasso=mod_opt.predict(df_pred)
df_pred["sale.price_lm"]=y1_pred_lm
df_pred["sale.price_lasso"]=y1_pred_lasso
sns.scatterplot(data=df1_train,x="gross.square.feet",y=y_train,alpha=0.4)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_lasso",color="red",alpha=0.5,marker="x",s=100)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_lm",color="green",alpha=0.5,marker="x",s=100)
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %%
# Testeo
df_pred=df1_test[covs].drop_duplicates().copy()
y1_pred_lm=mod_lin.predict(df_pred)
y1_pred_lasso=mod_opt.predict(df_pred)
df_pred["sale.price_lm"]=y1_pred_lm
df_pred["sale.price_lasso"]=y1_pred_lasso
sns.scatterplot(data=df1_test,x="gross.square.feet",y=y_test,alpha=0.4)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_lasso",color="red",alpha=0.5,marker="x",s=100)
sns.scatterplot(data=df_pred,x="gross.square.feet",y="sale.price_lm",color="green",alpha=0.5,marker="x",s=100)
plt.xlabel("Superficie [Pies^2]")
plt.ylabel("Precio de venta [Millones de USD]")
plt.yticks(ticks=[0,0.25e7,0.5e7,0.75e7,1e7],labels=[0,2.5,5,7.5,10])
plt.show()

# %% [markdown]
# # Ejercitación
#
# * Hacer un gráfico exploratorio de la siguiente base de salarios: [Salary Data](https://www.kaggle.com/datasets/mohithsairamreddy/salary-data).
# Eligir la variable de salario como respuesta.

# %%
import json
from google.colab import drive

# !mkdir ~/.kaggle
# !touch ~/.kaggle/kaggle.json

drive.mount('/content/drive', force_remount=True)
with open("/content/drive/My Drive/kaggle.json", 'r') as f:
    api_token= json.load(f)

with open('/root/.kaggle/kaggle.json', 'w') as file:
    json.dump(api_token, file)

# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# Mounted at /content/drive

# %%
# En el link aportado, copiar y pegar todo lo que le sigue a "/datasets/"
# !kaggle datasets download -d ______________________
# Out:
# Downloading salary-data.zip to /content
#   0% 0.00/16.6k [00:00<?, ?B/s]
# 100% 16.6k/16.6k [00:00<00:00, 32.0MB/s]

# %%
import zipfile
import os

os.listdir()

for file in os.listdir():
    if file.endswith('.zip'):
      zip_ref = zipfile.ZipFile(file, 'r')
      zip_ref.extractall()
      zip_ref.close()

# %%
import pandas as pd
# Examinar los archivos cargados seleccionando el ícono representando una carpeta que aparece a la izquierda
# Una vez identificada la base, acceder a las opciones con los tres puntos que aparecen a su derecha
# seleccionar "copiar ruta de archivo" o "copy path". Pegar con "Ctrl+v" esa ruta en la variable "path"
path=__________________
df=pd.read_csv(path)

# %%
df["Education Level"] = df["Education Level"].replace({ "Bachelor's Degree": "Bachelor's", "Master's Degree": "Master's", "phD": "PhD" })

# %%
df.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(data=df,x=____________,y="Salary",alpha=0.5)
# Nombrar correctamente los ejes
plt.xlabel("______")
plt.ylabel("______")
# Este comando obliga a Python a mostrar el gráfico
plt.show()

# %% [markdown]
# * Dividir en Train y Test. Hacer una regresión lineal para predecir el salario en función de otras variables. Para algunas variables cualitatitivas, generar variables dummies

# %%
from sklearn.model_selection import train_test_split
resp="Salary"
df_train, df_test, y_train, y_test = train_test_split(df.loc[:,df.columns!=resp], df[resp], test_size = 0.3, random_state = 25)

# %% [markdown]
# ### Selección de variables de salida y entrada

# %%
covs=[________________]
X=df[covs].copy()
y=df[resp].copy()
df_train, df_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 25)

# %% [markdown]
# ### Variables dummies

# %%
#Incluir las variables cualitativas que considere relevantes
df_train=pd.get_dummies(df_train,columns=["__________"])
df_test=pd.get_dummies(df_test,columns=[____________])

# %%
print(df_train.head())
print(df_train.info())
print(df_train.columns.values)
print(df_test.head())
print(df_test.info())
print(df_test.columns.values)

# %% [markdown]
# ### Inicialización

# %%
from sklearn.linear_model import LinearRegression
mod=LinearRegression()
mod.fit(df_train,y_train)

# %% [markdown]
# ### Predicciones

# %%
y_train_pred=mod.predict(df_train)
y_test_pred=mod.predict(df_test)

# %% [markdown]
# ### Evaluación

# %%
mse_lin_train=mean_squared_error(y_train,y_train_pred)
print("MSE train:"+str(mse_lin_train))
mse_lin_test=mean_squared_error(y_test,y_test_pred)
print("MSE test:"+str(mse_lin_test))

# %%
r2_train=mod.score(df_train,y_train)
print("R2 train:"+str(r2_train))
r2_test=mod.score(df_test,y_test)
print("R2 test:"+str(r2_test))

# %% [markdown]
# ### Evaluación gráfica

# %%
# Entrenamiento
df_pred=X_train.drop_duplicates().copy()
df_pred["Salary"]=mod.predict(df_pred)
sns.scatterplot(data=df_train,x=___________,y=y_train,alpha=0.4)
sns.scatterplot(data=df_pred,x=_______,y="Salary",color="red",alpha=0.5,marker="x",s=100)
plt.xlabel("___________")
plt.ylabel("___________")
plt.show()

# %%
# Testeo
df_pred=X_test.drop_duplicates().copy()
df_pred["Salary"]=mod.predict(df_pred)
sns.scatterplot(data=df_test,x=___________,y=y_test,alpha=0.4)
sns.scatterplot(data=df_pred,x=_______,y="Salary",color="red",alpha=0.5,marker="x",s=100)
plt.xlabel("___________")
plt.ylabel("___________")
plt.show()

# %% [markdown]
# * Usar ambas regularizaciones Ridge y Lasso, identificar el hiperparámetro óptimo y volver a realizar las predicciones para comparar las métricas y gráficas. Identificar a partir del gráfico un valor de alpha que permita anular algún coeficiente mediante el método de Lasso.

# %%
def regul_coefs(df_train,y_train,eMin,eMax,nExp,covs,Lasso=False):
  alphas = np.logspace(eMin, eMax, nExp)
  df_coef=pd.DataFrame({"Variable":covs})
  if Lasso:
    from sklearn.linear_model import Lasso
    modelo_temp = Lasso(alpha=alphas[0],fit_intercept=False)
    modelo_temp.fit(df_train[covs], y_train)
  else:
    from sklearn.linear_model import Ridge
    modelo_temp = Ridge(alpha=alphas[0],fit_intercept=False)
    modelo_temp.fit(df_train[covs], y_train)
  df_coef["Coeficientes"]=modelo_temp.coef_.flatten()
  df_coef["alpha"]=alphas[0]
  for alpha in alphas[1:]:
    df_coef_Aux=pd.DataFrame({"Variable":covs})
    if Lasso:
      modelo_temp = Lasso(alpha=alpha,fit_intercept=False)
      modelo_temp.fit(df_train[covs], y_train)
    else:
      modelo_temp = Ridge(alpha=alpha,fit_intercept=False)
      modelo_temp.fit(df_train[covs], y_train)
    df_coef_Aux["Coeficientes"]=modelo_temp.coef_.flatten()
    df_coef_Aux["alpha"]=alpha
    df_coef=pd.concat([df_coef,df_coef_Aux])
  return df_coef

# %%
def regul_rmse(df_train,df_test,y_train,y_test,eMin,eMax,nExp,covs,Lasso=False):
  alphas = np.logspace(eMin, eMax, nExp)
  if Lasso:
    from sklearn.linear_model import Lasso
    modelo_temp = Lasso(alpha=alphas[0],fit_intercept=False)
    modelo_temp.fit(df_train[covs], y_train)
  else:
    from sklearn.linear_model import Ridge
    modelo_temp = Ridge(alpha=alphas[0],fit_intercept=False)
    modelo_temp.fit(df_train[covs], y_train)
  y_pred_train = modelo_temp.predict(df_train[covs])
  rmse_train = root_mean_squared_error(y_train, y_pred_train)
  y_pred_test = modelo_temp.predict(df_test[covs])
  rmse_test = root_mean_squared_error(y_test, y_pred_test)
  indAux=0
  df_rmse=pd.DataFrame({"alpha":alphas[0],"rmse_train":rmse_train,"rmse_test":rmse_test},index=[indAux])
  for alpha in alphas[1:]:
    indAux=indAux+1
    if Lasso:
      modelo_temp = Lasso(alpha=alpha,fit_intercept=False)
      modelo_temp.fit(df_train[covs], y_train)
    else:
      modelo_temp = Ridge(alpha=alpha,fit_intercept=False)
      modelo_temp.fit(df_train[covs], y_train)
    y_pred_train = modelo_temp.predict(df_train[covs])
    rmse_train = root_mean_squared_error(y_train, y_pred_train)
    y_pred_test = modelo_temp.predict(df_test[covs])
    rmse_test = root_mean_squared_error(y_test, y_pred_test)
    df_rmse_Aux=pd.DataFrame({"alpha":alpha,"rmse_train":rmse_train,"rmse_test":rmse_test},index=[indAux])
    df_rmse=pd.concat([df_rmse,df_rmse_Aux])
  return df_rmse

# %%
df_coef_ridge=regul_coefs(df_train=df1_train,y_train=y_train,eMin=-1,eMax=5,nExp=400,covs=covs)

# %%
sns.lineplot(data=df_coef_ridge,x="alpha",y="Coeficientes",hue="Variable")
sns.color_palette("hls", 18)
plt.legend(bbox_to_anchor=(1.5, 1), borderaxespad=0)
plt.xscale('log')
plt.show()

# %%
df_rmse_ridge=regul_rmse(df_train=df1_train,df_test=df1_test,y_train=y_train,y_test=y_test,eMin=-4,eMax=5,nExp=400,covs=covs)

# %%
rango_alpha=df_rmse_ridge["alpha"]>0
plt.plot(df_rmse_ridge["alpha"].loc[rango_alpha],df_rmse_ridge["rmse_train"].loc[rango_alpha],c="b")
plt.plot(df_rmse_ridge["alpha"].loc[rango_alpha],df_rmse_ridge["rmse_test"].loc[rango_alpha],c="r")
plt.xlabel("Alpha")
plt.ylabel("RMSE")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
rango_alpha=df_rmse_ridge["alpha"]>0
id_optimo=df_rmse_ridge["rmse_test"].loc[rango_alpha].idxmin()
alpha_optimo=df_rmse_ridge["alpha"].iloc[id_optimo]

# %%
plt.plot(df_rmse_ridge["alpha"].loc[rango_alpha],df_rmse_ridge["rmse_train"].loc[rango_alpha],c="b")
plt.plot(df_rmse_ridge["alpha"].loc[rango_alpha],df_rmse_ridge["rmse_test"].loc[rango_alpha],c="r")
plt.axvline(
    x=alpha_optimo,
    c="gray",
    linestyle='--',
    label='óptimo'
)
plt.legend(loc='upper center')
plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
mod_opt = Ridge(alpha=alpha_optimo,fit_intercept=False)
mod_opt.fit(df1_train[covs], y_train)
y_train_pred = mod_opt.predict(df1_train[covs])
y_test_pred = mod_opt.predict(df1_test[covs])

# %%
print("RMSE train (Lineal):"+str(rmse_lin_train))
print("RMSE test (Lineal):"+str(rmse_lin_test))
rmse_rid_train=root_mean_squared_error(y_train,y_train_pred)
print("RMSE train (Ridge):"+str(rmse_rid_train))
rmse_rid_test=root_mean_squared_error(y_test,y_test_pred)
print("RMSE test (Ridge):"+str(rmse_rid_test))
